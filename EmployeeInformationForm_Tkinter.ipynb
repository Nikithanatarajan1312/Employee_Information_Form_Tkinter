# %% [markdown]
# EMPLOYEE INFORMATION FORM USING TKINTER

# %%
from tkinter import *
import tkinter.messagebox as MessageBox

def submit_022():
    name_022=entry_1_022.get()
    employee_id_022=entry_2_022.get()
    address_022=entry_3_022.get('1.0', END)
    phone_no_022=entry_4_022.get()
    date_022=entry_5_022.get()
    mail_022=entry_6_022.get()
    basic_pay_022=entry_7_022.get()
    ha_022=entry_8_022.get()
    da_022=entry_9_022.get()
    experience_022=entry_10_022.get()
    
    salary_022=float(basic_pay_022)+float(ha_022)+float(da_022)
    print("Salary of the employee:: Rs. ",salary_022)
    
    MessageBox.showinfo("Salary of the employee",salary_022)
            
root = Tk()
root.geometry("500x750")
root.title('Employee information form')

label_0_022 =Label(root,text="Employee information form", width=20,font=("bold",20))
label_0_022.place(x=90,y=10)


label_1_022 =Label(root,text="Employee Name", padx=20,font=("bold",10))
label_1_022.place(x=10,y=80)

entry_1_022=Entry(root)
entry_1_022.place(x=150,y=80)


label_2_022 =Label(root,text="Employee ID", padx=20,font=("bold",10))
label_2_022.place(x=10,y=130)

entry_2_022=Entry(root)
entry_2_022.place(x=150,y=130)


label_3_022 =Label(root,text="ADDRESS", padx=20,font=("bold",10))
label_3_022.place(x=10,y=180)

entry_3_022=Text(root)
entry_3_022.place(x=150,y=180, height = 65, width = 250)


label_4_022 =Label(root,text="Phone Number", padx=20,font=("bold",10))
label_4_022.place(x=10,y=270)

entry_4_022=Entry(root)
entry_4_022.place(x=150,y=270)


label_5_022 =Label(root,text="Date of Joining", padx=20,font=("bold",10))
label_5_022.place(x=10,y=320)

entry_5_022=Entry(root)
entry_5_022.place(x=150,y=320)


label_6_022 =Label(root,text="Mail ID", padx=20,font=("bold",10))
label_6_022.place(x=10,y=370)

entry_6_022=Entry(root)
entry_6_022.place(x=150,y=370)


label_7_022 =Label(root,text="Basic Pay", padx=20,font=("bold",10))
label_7_022.place(x=10,y=420)

entry_7_022=Entry(root)
entry_7_022.place(x=150,y=420)


label_8_022 =Label(root,text="HA", padx=20,font=("bold",10))
label_8_022.place(x=10,y=470)

entry_8_022=Entry(root)
entry_8_022.place(x=150,y=470)


label_9_022 =Label(root,text="DA", padx=20,font=("bold",10))
label_9_022.place(x=10,y=520)

entry_9_022=Entry(root)
entry_9_022.place(x=150,y=520)


label_10_022 =Label(root,text="Experience", padx=20,font=("bold",10))
label_10_022.place(x=10,y=570)

entry_10_022=Entry(root)
entry_10_022.place(x=150,y=570)


Button(root, text='Submit' , width=10,command=submit_022,bg='white').place(x=250,y=655)


root.mainloop()
# Out:
# Salary of the employee:: Rs.  163.0
